# %%
pip install folium
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in links: /usr/share/pip-wheels
# Collecting folium
#   Obtaining dependency information for folium from https://files.pythonhosted.org/packages/ae/6d/18a7546e1748ecdd6ed7cd00d3f183faf1df08bd4f5e5e0eb3e72458b862/folium-0.17.0-py2.py3-none-any.whl.metadata
#   Downloading folium-0.17.0-py2.py3-none-any.whl.metadata (3.8 kB)
# Collecting branca>=0.6.0 (from folium)
#   Obtaining dependency information for branca>=0.6.0 from https://files.pythonhosted.org/packages/75/ca/6074ab4a04dd1a503201c18091b3426f3709670115fae316907a97f98d75/branca-0.7.2-py3-none-any.whl.metadata
#   Downloading branca-0.7.2-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: jinja2>=2.9 in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from folium) (3.1.2)
# Requirement already satisfied: numpy in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from folium) (1.24.3)
# Requirement already satisfied: requests in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from folium) (2.31.0)
# Requirement already satisfied: xyzservices in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from folium) (2022.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from jinja2>=2.9->folium) (2.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from requests->folium) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from requests->folium) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from requests->folium) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from requests->folium) (2023.7.22)
# Downloading folium-0.17.0-py2.py3-none-any.whl (108 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.4/108.4 kB 2.8 MB/s eta 0:00:00.4 MB/s eta 0:00:01
# Downloading branca-0.7.2-py3-none-any.whl (25 kB)
# Installing collected packages: branca, folium
# Successfully installed branca-0.7.2 folium-0.17.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import folium

# %%
locations = [
    {"Store": "McDonald's", "Address": "541 6th Ave", "Latitude": 40.737049, "Longitude": -73.996925},
    {"Store": "McDonald's", "Address": "724 8th Ave", "Latitude": 40.758269, "Longitude": -73.988653},
    {"Store": "McDonald's", "Address": "220 W 42nd St", "Latitude": 40.755947, "Longitude": -73.988331},
    {"Store": "McDonald's", "Address": "335 5th Ave", "Latitude": 40.748336, "Longitude": -73.984645},
    {"Store": "McDonald's", "Address": "160 Broadway", "Latitude": 40.709707, "Longitude": -74.010807},
    {"Store": "McDonald's", "Address": "1188 Avenue of the Americas", "Latitude": 40.757664, "Longitude": -73.982745},
    {"Store": "McDonald's", "Address": "167 Chambers St", "Latitude": 40.715513, "Longitude": -74.010698},
    {"Store": "McDonald's", "Address": "429 7th Ave", "Latitude": 40.750526, "Longitude": -73.991641},
    {"Store": "McDonald's", "Address": "18 E 42nd St", "Latitude": 40.752262, "Longitude": -73.979451},
    {"Store": "McDonald's", "Address": "688 10th Ave", "Latitude": 40.762084, "Longitude": -73.992409},
    {"Store": "McDonald's", "Address": "262 Canal St", "Latitude": 40.718716, "Longitude": -74.001851},
    {"Store": "McDonald's", "Address": "280 Madison Ave", "Latitude": 40.751508, "Longitude": -73.980326},
    {"Store": "McDonald's", "Address": "263 6th Ave", "Latitude": 40.732213, "Longitude": -74.000763},
    {"Store": "McDonald's", "Address": "1560 Broadway", "Latitude": 40.759839, "Longitude": -73.985665},
    {"Store": "McDonald's", "Address": "429 Lexington Ave", "Latitude": 40.752859, "Longitude": -73.975709},
    {"Store": "McDonald's", "Address": "234 W 42nd St", "Latitude": 40.756681, "Longitude": -73.989266},
    {"Store": "McDonald's", "Address": "809 6th Ave", "Latitude": 40.746478, "Longitude": -73.991162},
    {"Store": "McDonald's", "Address": "501 6th Ave", "Latitude": 40.738424, "Longitude": -73.996646},
    {"Store": "McDonald's", "Address": "18 W 34th St", "Latitude": 40.750255, "Longitude": -73.987134},
    {"Store": "McDonald's", "Address": "197 Madison Ave", "Latitude": 40.748732, "Longitude": -73.983119},
    {"Store": "McDonald's", "Address": "427 10th Ave", "Latitude": 40.757533, "Longitude": -73.998588},
    {"Store": "McDonald's", "Address": "809 Avenue of the Americas", "Latitude": 40.745849, "Longitude": -73.993054},
    {"Store": "McDonald's", "Address": "26 Bowery", "Latitude": 40.715421, "Longitude": -73.996084},
    {"Store": "McDonald's", "Address": "154 Nassau St", "Latitude": 40.710294, "Longitude": -74.005901}
]
Manhatten_Map = folium.Map(location=[40.7831, -73.9712], zoom_start=12)

for location in locations:
    folium.Marker(
    location=[location["Latitude"], location["Longitude"]],
        popup=f"{location['Store']} - {location['Address']}",
    ).add_to(Manhatten_Map)
Manhatten_Map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8084b243e2a2fce7761a03223ac41402 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8084b243e2a2fce7761a03223ac41402&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8084b243e2a2fce7761a03223ac41402 = L.map(
#                 &quot;map_8084b243e2a2fce7761a03223ac41402&quot;,
#                 {
#                     center: [40.7831, -73.9712],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e9a12f5d79b23f1ba13bf5690fdbffe1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_e9a12f5d79b23f1ba13bf5690fdbffe1.addTo(map_8084b243e2a2fce7761a03223ac41402);
#
#
#             var marker_3c7a205db6837d0015132aaf27ac1eae = L.marker(
#                 [40.737049, -73.996925],
#                 {}
#             ).addTo(map_8084b243e2a2fce7761a03223ac41402);
#
#
#         var popup_46dc4cf069a22ef1654816aaed74bc92 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_082bc9f0adf09dc165ccd69961e2da61 = $(`&lt;div id=&quot;html_082bc9f0adf09dc165ccd69961e2da61&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;McDonald&#x27;s - 541 6th Ave&lt;/div&gt;`)[0];
#                 popup_46dc4cf069a22ef1654816aaed74bc92.setContent(html_082bc9f0adf09dc165ccd69961e2da61);
#
#
#
#         marker_3c7a205db6837d0015132aaf27ac1eae.bindPopup(popup_46dc4cf069a22ef1654816aaed74bc92)
#         ;
#
#
#
#
#             var marker_905eba088cf12fff8fe83e9c9f873571 = L.marker(
#                 [40.758269, -73.988653],
#                 {}
#             ).addTo(map_8084b243e2a2fce7761a03223ac41402);
#
#
#         var popup_52ac89ca229f94dce5b09b75db950581 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_180c38f2fd24a9c0016e015ac4c2d3d7 = $(`&lt;div id=&quot;html_180c38f2fd24a9c0016e015ac4c2d3d7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;McDonald&#x27;s - 724 8th Ave&lt;/div&gt;`)[0];
#                 popup_52ac89ca229f94dce5b09b75db950581.setContent(html_180c38f2fd24a9c0016e015ac4c2d3d7);
#
#
#
#         marker_905eba088cf12fff8fe83e9c9f873571.bindPopup(popup_52ac89ca229f94dce5b09b75db950581)
#         ;
#
#
#
#
#             var marker_2a14e0d8dc2968b81ba705927beaedac = L.marker(
#                 [40.755947, -73.988331],
#                 {}
#             ).addTo(map_8084b243e2a2fce7761a03223ac41402);
#
#
#         var popup_32f543a2648682814287c1c403596eda = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f7dd368ff09bddad4b06cf473558adb1 = $(`&lt;div id=&quot;html_f7dd368ff09bddad4b06cf473558adb1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;McDonald&#x27;s - 220 W 42nd St&lt;/div&gt;`)[0];
#                 popup_32f543a2648682814287c1c403596eda.setContent(html_f7dd368ff09bddad4b06cf473558adb1);
#
#
#
#         marker_2a14e0d8dc2968b81ba705927beaedac.bindPopup(popup_32f543a2648682814287c1c403596eda)
#         ;
#
#
#
#
#             var marker_21254b3606ebbe6abf423bccc3c309f3 = L.marker(
#                 [40.748336, -73.984645],
#                 {}
#             ).addTo(map_8084b243e2a2fce7761a03223ac41402);
#
#
#         var popup_ceb7ef9256cfee480c468f0037716926 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fde9805723fbe45bc3d3e40ecfeb7322 = $(`&lt;div id=&quot;html_fde9805723fbe45bc3d3e40ecfeb7322&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;McDonald&#x27;s - 335 5th Ave&lt;/div&gt;`)[0];
#                 popup_ceb7ef9256cfee480c468f0037716926.setContent(html_fde9805723fbe45bc3d3e40ecfeb7322);
#
#
#
#         marker_21254b3606ebbe6abf423bccc3c309f3.bindPopup(popup_ceb7ef9256cfee480c468f0037716926)
#         ;
#
#
#
#
#             var marker_3101842816891cec224029c0de8a60f5 = L.marker(
#                 [40.709707, -74.010807],
#                 {}
#             ).addTo(map_8084b243e2a2fce7761a03223ac41402);
#
#
#         var popup_274a1482978df457187253829fed904d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2c70577ebdd32cd7c94c088b7c793d92 = $(`&lt;div id=&quot;html_2c70577ebdd32cd7c94c088b7c793d92&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;McDonald&#x27;s - 160 Broadway&lt;/div&gt;`)[0];
#                 popup_274a1482978df457187253829fed904d.setContent(html_2c70577ebdd32cd7c94c088b7c793d92);
#
#
#
#         marker_3101842816891cec224029c0de8a60f5.bindPopup(popup_274a1482978df457187253829fed904d)
#         ;
#
#
#
#
#             var marker_5c355d24efa1d556761f6c9044215d2d = L.marker(
#                 [40.757664, -73.

# %%
import pandas as pd

# %%
df = pd.DataFrame(locations)
df
# Out:
#          Store                      Address   Latitude  Longitude
# 0   McDonald's                  541 6th Ave  40.737049 -73.996925
# 1   McDonald's                  724 8th Ave  40.758269 -73.988653
# 2   McDonald's                220 W 42nd St  40.755947 -73.988331
# 3   McDonald's                  335 5th Ave  40.748336 -73.984645
# 4   McDonald's                 160 Broadway  40.709707 -74.010807
# 5   McDonald's  1188 Avenue of the Americas  40.757664 -73.982745
# 6   McDonald's              167 Chambers St  40.715513 -74.010698
# 7   McDonald's                  429 7th Ave  40.750526 -73.991641
# 8   McDonald's                 18 E 42nd St  40.752262 -73.979451
# 9   McDonald's                 688 10th Ave  40.762084 -73.992409
# 10  McDonald's                 262 Canal St  40.718716 -74.001851
# 11  McDonald's              280 Madison Ave  40.751508 -73.980326
# 12  McDonald's                  263 6th Ave  40.732213 -74.000763
# 13  McDonald's                1560 Broadway  40.759839 -73.985665
# 14  McDonald's            429 Lexington Ave  40.752859 -73.975709
# 15  McDonald's                234 W 42nd St  40.756681 -73.989266
# 16  McDonald's                  809 6th Ave  40.746478 -73.991162
# 17  McDonald's                  501 6th Ave  40.738424 -73.996646
# 18  McDonald's                 18 W 34th St  40.750255 -73.987134
# 19  McDonald's              197 Madison Ave  40.748732 -73.983119
# 20  McDonald's                 427 10th Ave  40.757533 -73.998588
# 21  McDonald's   809 Avenue of the Americas  40.745849 -73.993054
# 22  McDonald's                    26 Bowery  40.715421 -73.996084
# 23  McDonald's                154 Nassau St  40.710294 -74.005901

# %%
pip install geopy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in links: /usr/share/pip-wheels
# Collecting geopy
#   Obtaining dependency information for geopy from https://files.pythonhosted.org/packages/e5/15/cf2a69ade4b194aa524ac75112d5caac37414b20a3a03e6865dfe0bd1539/geopy-2.4.1-py3-none-any.whl.metadata
#   Downloading geopy-2.4.1-py3-none-any.whl.metadata (6.8 kB)
# Collecting geographiclib<3,>=1.52 (from geopy)
#   Obtaining dependency information for geographiclib<3,>=1.52 from https://files.pythonhosted.org/packages/9f/5a/a26132406f1f40cf51ea349a5f11b0a46cec02a2031ff82e391c2537247a/geographiclib-2.0-py3-none-any.whl.metadata
#   Downloading geographiclib-2.0-py3-none-any.whl.metadata (1.4 kB)
# Downloading geopy-2.4.1-py3-none-any.whl (125 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.4/125.4 kB 4.5 MB/s eta 0:00:00
# Downloading geographiclib-2.0-py3-none-any.whl (40 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.3/40.3 kB 1.3 MB/s eta 0:00:00
# Installing collected packages: geographiclib, geopy
# Successfully installed geographiclib-2.0 geopy-2.4.1
# Note: you may need to restart the kernel to use updated packages.

# %%
from geopy.distance import geodesic
import itertools

# %%
coords = [(loc["Latitude"], loc["Longitude"]) for loc in locations]
distances = []

for (lat1, lon1), (lat2, lon2) in itertools.combinations(coords, 2):
    distances.append(geodesic((lat1, lon1), (lat2, lon2)).kilometers)

avg_distance = sum(distances) / len(distances)

print("The average distance from each Mcdonalds store in Manhatten is",avg_distance,'Km')
# Out:
# The average distance from each Mcdonalds store in Manhatten is 2.3381540464515336 Km
